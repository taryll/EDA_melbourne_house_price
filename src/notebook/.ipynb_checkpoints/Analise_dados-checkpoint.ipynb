# %% [markdown]
# ## Biblioteca

# %%
import pandas as pd
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Analizando do menos detalhado para mais detalhado. No caso, Região ou bairro da propriedade é "menos detalhado" do que quantidade de quartos ou banheiros da casa.

# %% [markdown]
# Agora que foi feita um primeiro preprocessamento dos dados, vamos levantar algumas hipóteses sobre os dados e tentar responder elas através das análises de dados. Em geral podemos montar tabelas e gráficos para uma melhor visualização dos dados.

# %% [markdown]
# Qual a relação das variáveis com o preço das casas?
#
# O vendedor importa na hora de venda ou preço?

# %%
df_clean = pd.read_csv('../../data/processed/df_clean.csv')
df_clean.sample(5, random_state = 12)
# Out:
#             Suburb          Address  Rooms Type      Price Method   SellerG  \
# 11058  Collingwood   43 Campbell St      2    h  1135000.0      S       Kay
# 5309       Preston        43 May St      2    h   876000.0      S    Nelson
# 8213     Doncaster      4/2 Paul St      4    t  1090000.0      S     Barry
# 23562          Kew     5 Majella Ct      3    h  3300000.0     VB  Marshall
# 3940           Kew  8 Carnsworth Av      4    h  1830000.0     PI       Kay
#
#              Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 11058  27/05/2017       2.0    3066.0       2.0       1.0  0.0     144.0
# 5309   18/03/2017       8.8    3072.0       2.0       1.0  2.0     479.0
# 8213   22/04/2017      13.9    3108.0       4.0       3.0  2.0     242.0
# 23562  17/03/2018       5.4    3101.0       3.0       2.0  2.0     844.0
# 3940   27/11/2016       5.6    3101.0       NaN       NaN  NaN       NaN
#
#        BuildingArea  YearBuilt              CouncilArea  \
# ...

# %% [markdown]
# Vamos retirar algumas variáveis que não entrarão na EDA. São eles: 'Address', 'Postcode', 'Propertycount'.

# %%
df_eda = df_clean.drop(['Address', 'Postcode'], axis = 1)

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
plt.figure(figsize = (12, 8))
sns.histplot(data = df_eda, x = 'Price', kde = True)
plt.ticklabel_format(style = 'plain', axis = 'x')
plt.axvline(df_clean['Price'].mean(), c = 'red', label = 'média de preço')
plt.axvline(df_clean['Price'].median(), c = 'black', label = 'mediana de preço')
plt.legend()
plt.show()

# %%
df_eda.loc[:, ['Price']].describe()
# Out:
#             Price
# count    24599.00
# mean   1062744.69
# std     615955.99
# min     112000.00
# 25%     655000.00
# 50%     895000.00
# 75%    1300000.00
# max   11200000.00

# %%
suburb_mean = df_eda.loc[:, ['Suburb', 'Price']].groupby('Suburb').mean()
suburb_mean_sort = suburb_mean.sort_values(by = 'Price', ascending = False)

# %%
suburb_mean_sort.head(5).reset_index()
# Out:
#         Suburb      Price
# 0      Malvern 2325607.53
# 1   Canterbury 2304727.27
# 2  Middle Park 2195081.63
# 3     Deepdene 2001785.71
# 4     Brighton 1988331.25

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (14, 8))

sns.barplot(x = 'Price', y = 'Suburb', data = suburb_mean_sort.head(5).reset_index(), ax = ax1)
ax1.ticklabel_format(style = 'plain', axis = 'x')
ax1.set_title(label = 'Top 5 média de preços de imóveis para cada bairro')
ax1.set_xlim(right = 2500000)

sns.barplot(x = 'Price', y = 'Suburb', data = suburb_mean_sort.tail(5).reset_index(), ax = ax2)
ax2.ticklabel_format(style = 'plain', axis = 'x')
ax2.set_title(label = 'Bottom 5 média de preços de imóveis de cada bairro')
ax2.set_xlim(right = 2500000)

fig.tight_layout(pad=3.0)

plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.barplot(x = 'Price', y = 'Suburb', data = suburb_mean_sort.head(5).reset_index())
plt.ticklabel_format(style = 'plain', axis = 'x')
plt.title(label = 'Top 5 média de preços de imóveis para cada bairro')
plt.xlim(right = 2500000)
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.barplot(x = 'Price', y = 'Suburb', data = suburb_mean_sort.tail(5).reset_index())
plt.ticklabel_format(style = 'plain', axis = 'x')
plt.title(label = 'Bottom 5 média de preços de imóveis de cada bairro')
plt.xlim(right = 2500000)
plt.show()

# %% [markdown]
# Bairros mais caros: Canterbury, Middle Park, Malvern e Deepdene
#
# Bairros mais baratos: Darley, Kurunjang, Bacchus, Marsh
#
# Será que são bairros periféricos e outros mais perto de CBD?

# %%
df_eda.loc[:, ['Suburb', 'Distance', 'Price']].groupby(['Suburb']).mean().sort_values(by = 'Price', ascending = False)
# Out:
#                Distance      Price
# Suburb
# Malvern            6.63 2325607.53
# Canterbury         8.70 2304727.27
# Middle Park        3.52 2195081.63
# Deepdene           7.90 2001785.71
# Brighton          10.87 1988331.25
# ...                 ...        ...
# Melton            31.70  425086.21
# Melton South      29.80  423886.36
# Bacchus Marsh     37.50  423000.00
# Kurunjang         31.70  380653.85
# Darley            37.50  380000.00
#
# [339 rows x 2 columns]

# %% [markdown]
# Parece sim ter alguma relação. Vejamos o gráfico a seguir.

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x = 'Distance', y = 'Price', data = df_eda)
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.axvline(20, c = 'red', label = 'x = 20')
plt.axhline(3200000, c = 'red', label = 'y = 3200000')
plt.legend()
plt.show()

# %% [markdown]
# Olhando o gráfico de dispersão, parece ter uma relação sim, já que os valores acima de 3200000 possuem distância menor que 20. Acima dessa distância, temos preços a baixo disso.

# %%
region_mean = df_eda.loc[:, ['Regionname', 'Price', 'Distance']].groupby(['Regionname']).mean()
region_mean_sort = region_mean.sort_values(by = 'Distance', ascending = True)
region_mean_sort
# Out:
#                                 Price  Distance
# Regionname
# Southern Metropolitan      1454245.91      9.27
# Northern Metropolitan       876990.98      9.63
# Western Metropolitan        844423.16     11.04
# Eastern Metropolitan       1094550.40     14.63
# South-Eastern Metropolitan  873593.34     24.29
# Western Victoria            429864.36     30.80
# Northern Victoria           589641.45     32.32
# Eastern Victoria            696690.67     34.31

# %%
region_mean = df_eda.loc[:, ['Regionname', 'Price']].groupby(['Regionname']).mean()
region_mean_sort = region_mean.sort_values(by = 'Price', ascending = False)
region_mean_sort
# Out:
#                                 Price
# Regionname
# Southern Metropolitan      1454245.91
# Eastern Metropolitan       1094550.40
# Northern Metropolitan       876990.98
# South-Eastern Metropolitan  873593.34
# Western Metropolitan        844423.16
# Eastern Victoria            696690.67
# Northern Victoria           589641.45
# Western Victoria            429864.36

# %%
plt.figure(figsize = (10, 8))
sns.barplot(x = 'Price', y = 'Regionname', data = region_mean_sort.reset_index())
plt.ticklabel_format(style = 'plain', axis = 'x')
# plt.title(label = 'Média de preço de cada região ordenado pela distância')
plt.show()

# %%
region_mean_dist = df_eda.loc[:, ['Regionname', 'Distance']].groupby(['Regionname']).mean()
region_mean_dist_sort = region_mean_dist.sort_values(by = 'Distance', ascending = False)

# %%
plt.figure(figsize = (10, 8))
sns.barplot(x = 'Distance', y = 'Regionname', data = region_mean_dist_sort.reset_index())
plt.ticklabel_format(style = 'plain', axis = 'x')
plt.title(label = 'Média de distância de cada região')
plt.show()

# %% [markdown]
# Regiões mais caras em ordem. Novamente, pela tabela abaixo, a distância tem um impacto forte no preço das propriedades.

# %%
df_eda.loc[:, ['Regionname', 'Distance', 'Price']].groupby(['Regionname', 'Distance']).mean().sort_values(by = 'Price', ascending = False)
# Out:
#                                     Price
# Regionname            Distance
# Southern Metropolitan 9.00     2301769.23
#                       5.90     2247490.38
#                       3.00     2140968.25
#                       7.40     2112981.13
#                       10.50    2001275.79
# ...                                   ...
# Western Metropolitan  27.70     456428.57
# Western Victoria      29.80     433462.50
#                       31.70     425086.21
# Northern Victoria     31.70     422780.49
# Western Victoria      37.50     414400.00
#
# [294 rows x 1 columns]

# %%
df_eda.loc[:, ['Regionname', 'CouncilArea', 'Price']].groupby(['CouncilArea', 'Regionname']).mean()
# Out:
#                                                                Price
# CouncilArea                    Regionname
# Banyule City Council           Eastern Metropolitan       1000634.43
#                                Northern Metropolitan       802001.74
# Bayside City Council           Southern Metropolitan      1566323.10
# Boroondara City Council        Eastern Metropolitan       1514821.88
#                                Southern Metropolitan      1693703.58
# Brimbank City Council          Western Metropolitan        677856.78
# Cardinia Shire Council         Eastern Victoria            559440.00
# Casey City Council             Eastern Victoria            779921.05
#                                South-Eastern Metropolitan  628627.80
# Darebin City Council           Northern Metropolitan       914520.94
# Frankston City Council         Eastern Victoria            525860.00
#                                South-Eastern Metropolitan  719505.68
# ...

# %%
df_eda.loc[:, ['Suburb', 'Propertycount', 'Price']].groupby(['Suburb', 'Propertycount']).mean()
# Out:
#                                 Price
# Suburb       Propertycount
# Abbotsford   4019.00       1084011.11
# Aberfeldie   1543.00       1331550.85
# Airport West 3464.00        741723.41
# Albanvale    1899.00        536055.56
# Albert Park  3280.00       1957906.98
# ...                               ...
# Yallambie    1369.00        817017.05
# Yarra Glen   1160.00        620000.00
# Yarraville   6543.00       1023213.71
# croydon      11925.00       730000.00
# viewbank     2698.00        885000.00
#
# [339 rows x 1 columns]

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x = 'Propertycount', y = 'Price', data = df_eda)
plt.ticklabel_format(style = 'plain', axis = 'y')
# plt.axvline(25, c = 'red', label = 'x = 25')
# plt.axhline(3000000, c = 'red', label = 'y = 3000000')
# plt.legend()
plt.show()

# %% [markdown]
# Já o conselho tutelar parece não ter uma relação com o preço.
#
# Em seguida temos a tabela de Type, onde h e t representam casas e u representa apartamentos.

# %%
type_mean = df_eda.loc[:, ['Type', 'Price']].groupby(['Type']).mean()

plt.figure(figsize = (10, 8))
sns.barplot(x = 'Type', y = 'Price', data = type_mean.reset_index())
plt.ticklabel_format(style = 'plain', axis = 'y')
# plt.title(label = 'Média de distância de cada região')
plt.show()

# %%
plt.figure(figsize = (12, 10))
sns.boxplot(x = 'Bedroom2', y = 'Price', data = df_eda)
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(x = 'Bathroom', y = 'Price', data = df_eda)
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(x = 'Car', y = 'Price', data = df_eda)
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x = 'YearBuilt', y = 'Price', data = df_eda)
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x = 'Landsize', y = 'Price', data = df_eda, hue = 'Bathroom', palette = 'muted')
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.show()

# %%
df_eda.loc[df_clean['Type'] == 'h', ['Price']].describe()
# Out:
#             Price
# count    17642.00
# mean   1183314.73
# std     652366.20
# min     131000.00
# 25%     741000.00
# 50%    1006000.00
# 75%    1430000.00
# max   11200000.00

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x = 'Bedroom2', y = 'Price', data = df_eda)
plt.ticklabel_format(style = 'plain', axis = 'y')
# plt.axvline(25, c = 'red', label = 'x = 25')
# plt.axhline(3000000, c = 'red', label = 'y = 3000000')
# plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x = 'Landsize', y = 'BuildingArea', data = df_eda)
plt.ticklabel_format(style = 'plain', axis = 'y')
# plt.axvline(25, c = 'red', label = 'x = 25')
# plt.axhline(3000000, c = 'red', label = 'y = 3000000')
# plt.legend()
plt.show()

# %%
def scat_plot(x, y, data):
    sns.regplot(x = x, y = y, data = data, order = 2,
                scatter_kws = {"color": "steelblue"}, line_kws = {"color": "black"})
    plt.ticklabel_format(style = 'plain', axis = 'y')
    plt.title(x)
    plt.show()

# %%
columns = ['Distance', 'Bedroom2', 'Bathroom',  
           'Car', 'YearBuilt', 'Propertycount']

for i in columns:
    scat_plot(i, 'Price', df_eda)

# %%
df_eda['Date'] = pd.to_datetime(df_eda['Date'])
df_eda['Year'] = df_eda['Date'].dt.year
df_eda['Month'] = df_eda['Date'].dt.month
df_eda['YearMonth'] = df_eda['Date'].dt.strftime('%Y-%m')

# %%
df_eda.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG       Date  Distance  \
# 0  Abbotsford      2    h 1480000.00      S  Biggin 2016-03-12      2.50
# 1  Abbotsford      2    h 1035000.00      S  Biggin 2016-04-02      2.50
# 2  Abbotsford      3    h 1465000.00     SP  Biggin 2017-04-03      2.50
# 3  Abbotsford      3    h  850000.00     PI  Biggin 2017-04-03      2.50
# 4  Abbotsford      4    h 1600000.00     VB  Nelson 2016-04-06      2.50
#
#    Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0      2.00      1.00 1.00    202.00           NaN        NaN
# 1      2.00      1.00 0.00    156.00         79.00    1900.00
# 2      3.00      2.00 0.00    134.00        150.00    1900.00
# 3      3.00      2.00 1.00     94.00           NaN        NaN
# 4      3.00      1.00 2.00    120.00        142.00    2014.00
#
#           CouncilArea             Regionname  Propertycount YearMonth  Year  \
# ...

# %%
df_eda_filt = df_eda[~df_eda.loc[:, 'YearMonth'].isin(['2018-06', '2018-10'])]
year_month_total = df_eda_filt.loc[:, ['Year', 'Month', 'Price']].groupby(['Year', 'Month']).sum()

# %%
plt.figure(figsize = (10, 8))

sns.scatterplot(x = 'Month', y = 'Price', data = year_month_total, hue = 'Year', palette = 'deep', s = 500)

plt.ticklabel_format(style = 'plain', axis = 'y')

plt.xticks(rotation = 25)

plt.show()

# %%
df_eda_filt_year = df_eda_filt[df_eda_filt.loc[:, 'Year'].isin([2016, 2017])]
df_eda_suburb_prices = df_eda_filt_year.loc[:, ['Suburb', 'Price', 'Year']].groupby(['Suburb', 'Year'])
df_eda_suburb_prices = df_eda_suburb_prices.mean('Price').unstack()
df_eda_suburb_prices['Diff'] = df_eda_suburb_prices[('Price', 2017)] - df_eda_suburb_prices[('Price', 2016)]
df_eda_suburb_prices.sort_values(by = 'Diff', ascending = False).dropna()
# Out:
#                         Price                   Diff
# Year                     2016       2017
# Suburb
# Middle Park        1874000.00 2321384.62   447384.62
# Essendon West       990275.00 1335875.00   345600.00
# Williamstown North  832000.00 1134363.64   302363.64
# Ivanhoe            1095972.73 1380815.48   284842.75
# Oakleigh            941196.43 1206378.05   265181.62
# ...                       ...        ...         ...
# Docklands           922500.00  612500.00  -310000.00
# Kew                2014041.24 1678587.88  -335453.36
# Toorak             2263325.58 1725098.48  -538227.10
# Caulfield          1393750.00  512000.00  -881750.00
# Gardenvale         2200000.00  941285.71 -1258714.29
#
# [142 rows x 3 columns]

# %% [markdown]
# ### Resuminho

# %% [markdown]
# - Há bairros/regiões em que as propriedades são mais valiosas. Essas regiões costumam ficar mais próximas de CBD de Melbourne. Podemos dizer mais ou menos em regiões centrais mais valiosas do que regiões periféricas;
# - Conselho tutelar parece não agregar muito valor.
# - Type: h > t > u, h costuma ser casas maiores, t é townhouse e h são apartamentos.
# - Bedroom2 e Bathroom parece ter uma tendência linear. Quanto mais, maior o preço.
# - Vaga de carro e ano construído não mostra uma relação clara nos gráficos.
# - Landsize, BuildingArea não parecem consistentes. Rooms tem inconsistência, melhor usar só o Bedroom2.
# - Address, Postcode e SellerG não entrará nas análises.
# - Date pode ser usado para séries, junto com Method para separar as casas vendidas ou não. Também criar janelas com preço de médias móveis e olhar a tendência dos preços num geral e ver o comportamento do mercado imobiliário.
# - Propertycount tem relação direta com o Suburb, mas não está claro a relação com o preço.
