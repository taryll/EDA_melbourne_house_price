# %% [markdown]
# ## Biblioteca

# %%
import pandas as pd
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Analizando do menos detalhado para mais detalhado. No caso, Região ou bairro da propriedade é "menos detalhado" do que quantidade de quartos ou banheiros da casa.

# %% [markdown]
# Agora que foi feita um primeiro preprocessamento dos dados, vamos levantar algumas hipóteses sobre os dados e tentar responder elas através das análises de dados. Em geral podemos montar tabelas e gráficos para uma melhor visualização dos dados.

# %% [markdown]
# Qual a relação das variáveis com o preço das casas?
#
# O vendedor importa na hora de venda ou preço?

# %%
df_clean = pd.read_csv('../../data/processed/df_clean.csv')
df_clean.sample(5)
# Out:
#              Suburb           Address  Rooms Type      Price Method   SellerG  \
# 11392     Doncaster     192 George St      3    h  1285000.0     SA       Ray
# 24792    Black Rock      211 Beach Rd      4    h  2720000.0      S    Buxton
# 11511  Malvern East        7 Nyora St      3    h  2265000.0      S  Marshall
# 5083    Mont Albert  12 Rostrevor Pde      4    h  2335000.0      S       Kay
# 13390  Hampton Park       75 Pound Rd      4    h   622000.0     SP        FN
#
#              Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 11392   3/06/2017      12.4    3108.0       3.0       1.0  2.0     645.0
# 24792  17/02/2018      17.3    3193.0       4.0       3.0  4.0     604.0
# 11511   3/06/2017       8.4    3145.0       3.0       2.0  2.0     531.0
# 5083   18/03/2017      11.8    3127.0       4.0       2.0  2.0     813.0
# 13390   8/07/2017      33.3    3976.0       4.0       2.0  2.0     654.0
#
#        BuildingArea    YearBuilt               CouncilArea  \
# 11392    146.924069  1966.563627   Manningham City Council
# 24792    146.924069  1966.563627      Bayside City Council
# 11511    146.924069  1966.563627  Stonnington City Council
# 5083     170.000000  1938.000000   Boroondara City Council
# 13390    146.924069  1989.000000        Casey City Council
#
#                        Regionname  Propertycount
# 11392        Eastern Metropolitan         9028.0
# 24792       Southern Metropolitan         2866.0
# 11511       Southern Metropolitan         8801.0
# 5083         Eastern Metropolitan         2079.0
# 13390  South-Eastern Metropolitan         8256.0

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
plt.figure(figsize = (12, 8))
sns.histplot(data = df_clean, x = 'Price', kde = True)
plt.ticklabel_format(style = 'plain', axis = 'x')
plt.axvline(df_clean['Price'].mean(), c = 'red', label = 'média de preço')
plt.axvline(df_clean['Price'].median(), c = 'black', label = 'mediana de preço')
plt.legend()
plt.show()

# %%
df_clean.loc[:, ['Price']].describe()
# Out:
#             Price
# count    26599.00
# mean   1031936.98
# std     610207.52
# min      85000.00
# 25%     631000.00
# 50%     864000.00
# 75%    1275000.00
# max   11200000.00

# %%
df_clean.loc[:, ['Suburb', 'Price']].groupby('Suburb').mean().sort_values(by = 'Price', ascending = False)
# Out:
#                    Price
# Suburb
# Canterbury    2246395.06
# Middle Park   2103096.15
# Malvern       2005339.13
# Deepdene      2001785.71
# Albert Park   1915994.57
# ...                  ...
# Melton         425086.21
# Melton South   423886.36
# Bacchus Marsh  423000.00
# Kurunjang      380653.85
# Darley         380000.00
#
# [339 rows x 1 columns]

# %% [markdown]
# Bairros mais caros: Canterbury, Middle Park, Malvern e Deepdene
#
# Bairros mais baratos: Darley, Kurunjang, Bacchus, Marsh
#
# Será que são bairros periféricos e outros mais perto de CBD?

# %%
df_clean.loc[:, ['Suburb', 'Distance', 'Price']].groupby(['Suburb', 'Distance']).mean().sort_values(by = 'Price', ascending = False)
# Out:
#                             Price
# Suburb        Distance
# Middle Park   3.00     2453000.00
# Canterbury    8.40     2307763.16
# Malvern       5.90     2205774.51
# Canterbury    9.00     2192162.79
# Deepdene      7.90     2001785.71
# ...                           ...
# Melton        31.70     425086.21
# Melton South  29.80     423886.36
# Bacchus Marsh 37.50     423000.00
# Kurunjang     31.70     380653.85
# Darley        37.50     380000.00
#
# [479 rows x 1 columns]

# %% [markdown]
# Parece sim ter alguma relação. Vejamos o gráfico a seguir.

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x = 'Distance', y = 'Price', data = df_clean)
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.axvline(25, c = 'red', label = 'x = 25')
plt.axhline(3000000, c = 'red', label = 'y = 3000000')
plt.legend()
plt.show()

# %% [markdown]
# Olhando o gráfico de dispersão, parece ter uma relação sim, já que os valores acima de 3000000 possuem distância menor que 25. Acima dessa distância, temos preços a baixo disso.

# %%
df_clean.loc[:, ['Regionname', 'Price']].groupby(['Regionname']).mean().sort_values(by = 'Price', ascending = False)
# Out:
#                                 Price
# Regionname
# Southern Metropolitan      1358836.59
# Eastern Metropolitan       1087684.44
# South-Eastern Metropolitan  871698.84
# Northern Metropolitan       857383.25
# Western Metropolitan        828868.20
# Eastern Victoria            696519.36
# Northern Victoria           589641.45
# Western Victoria            429864.36

# %%
df_clean.loc[:, ['Regionname', 'Distance', 'Price']].groupby(['Regionname', 'Distance']).mean().sort_values(by = 'Price', ascending = False)
# Out:
#                                     Price
# Regionname            Distance
# Southern Metropolitan 9.00     2192162.79
#                       5.90     2152263.64
#                       3.00     2140968.25
#                       10.50    1953321.43
#                       8.40     1929197.84
# ...                                   ...
# Western Metropolitan  27.70     456428.57
# Western Victoria      29.80     433462.50
#                       31.70     425086.21
# Northern Victoria     31.70     422780.49
# Western Victoria      37.50     414400.00
#
# [294 rows x 1 columns]

# %%
df_clean.loc[:, ['Regionname', 'CouncilArea', 'Price']].groupby(['CouncilArea', 'Regionname']).mean()
# Out:
#                                                                Price
# CouncilArea                    Regionname
# Banyule City Council           Eastern Metropolitan        990758.67
#                                Northern Metropolitan       800680.28
# Bayside City Council           Southern Metropolitan      1534341.74
# Boroondara City Council        Eastern Metropolitan       1441234.97
#                                Southern Metropolitan      1603689.68
# Brimbank City Council          Western Metropolitan        676001.13
# Cardinia Shire Council         Eastern Victoria            559440.00
# Casey City Council             Eastern Victoria            779921.05
#                                South-Eastern Metropolitan  628627.80
# Darebin City Council           Northern Metropolitan       894502.85
# Frankston City Council         Eastern Victoria            523596.15
#                                South-Eastern Metropolitan  717203.62
# Glen Eira City Council         Southern Metropolitan      1109359.76
# Greater Dandenong City Council South-Eastern Metropolitan  688317.82
# Hobsons Bay City Council       Western Metropolitan        989357.71
# Hume City Council              Northern Metropolitan       591082.12
#                                Western Metropolitan        566427.46
# Kingston City Council          South-Eastern Metropolitan  945518.21
#                                Southern Metropolitan       996740.83
# Knox City Council              Eastern Metropolitan        872514.86
#                                South-Eastern Metropolitan  915751.52
# Macedon Ranges Shire Council   Northern Victoria           675672.41
# Manningham City Council        Eastern Metropolitan       1205687.70
#                                Eastern Victoria           1357500.00
# Maribyrnong City Council       Western Metropolitan        821479.28
# Maroondah City Council         Eastern Metropolitan        894014.27
# Melbourne City Council         Northern Metropolitan       991144.17
#                                Southern Metropolitan      1108630.93
# Melton City Council            Northern Victoria           422780.49
#                                Western Metropolitan        612545.83
#                                Western Victoria            430733.15
# Mitchell Shire Council         Northern Victoria           519200.00
# Monash City Council            Eastern Metropolitan       1321413.62
#                                South-Eastern Metropolitan 1125194.48
#                                Southern Metropolitan      1110687.99
# Moonee Valley City Council     Western Metropolitan       1017688.36
# Moorabool Shire Council        Western Victoria            414400.00
# Moreland City Council          Northern Metropolitan       851440.98
#                                Western Metropolitan        721872.09
# Nillumbik Shire Council        Eastern Metropolitan        986818.18
#                                Northern Victoria           670046.15
# Port Phillip City Council      Southern Metropolitan      1124732.52
# Stonnington City Council       Southern Metropolitan      1543967.77
# Whitehorse City Council        Eastern Metropolitan       1146768.50
# Whittlesea City Council        Northern Metropolitan       621699.35
#                                Northern Victoria           489000.00
# Wyndham City Council           Western Metropolitan        563303.40
# Yarra City Council             Northern Metropolitan      1096330.33
# Yarra Ranges Shire Council     Eastern Victoria            750991.78
#                                Northern Victoria           665333.33

# %%
df_clean.loc[:, ['Type', 'Price']].groupby(['Type']).mean()
# Out:
#           Price
# Type
# h    1181690.71
# t     928636.51
# u     627281.60

# %%
df_clean[df_clean['Bathroom'] == 0].shape
# Out:
# (28, 19)

# %%
1930/26599 * 100
# Out:
# 7.25591187638633

# %%
df_clean.loc[df_clean['Type'] == 'h', ['Price']].describe()
# Out:
#          Rooms       Price  Distance  Postcode  Bedroom2  Bathroom      Car  \
# count 17864.00    17864.00  17864.00  17864.00  17864.00  17864.00 17864.00
# mean      3.28  1181690.71     12.31   3115.84      3.21      1.60     1.75
# std       0.79   651484.62      7.11    124.89      0.72      0.58     0.82
# min       1.00   131000.00      1.20   3000.00      1.00      0.00     0.00
# 25%       3.00   740000.00      7.50   3044.00      3.00      1.00     1.00
# 50%       3.00  1005000.00     11.20   3083.00      3.00      1.55     2.00
# 75%       4.00  1430000.00     14.80   3149.00      4.00      2.00     2.00
# max      12.00 11200000.00     48.10   3978.00      5.00      3.00     4.00
#
#        Landsize  BuildingArea  YearBuilt  Propertycount
# count  17864.00      17864.00   17864.00       17864.00
# mean     534.95        154.06    1962.88        7372.60
# std      328.20         54.65      25.42        4467.37
# min        0.00          0.00    1857.00         121.00
# 25%      450.75        146.92    1965.00        4019.00
# 50%      498.99        146.92    1966.56        6380.00
# 75%      637.00        146.92    1966.56       10331.00
# max    10120.00       1041.00    2019.00       21650.00

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x = 'BuildingArea', y = 'Price', data = df_clean)
plt.ticklabel_format(style = 'plain', axis = 'y')
# plt.axvline(25, c = 'red', label = 'x = 25')
# plt.axhline(3000000, c = 'red', label = 'y = 3000000')
# plt.legend()
plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.scatterplot(x = 'Landsize', y = 'Price', data = df_clean)
plt.ticklabel_format(style = 'plain', axis = 'y')
# plt.axvline(25, c = 'red', label = 'x = 25')
# plt.axhline(3000000, c = 'red', label = 'y = 3000000')
# plt.legend()
plt.show()

# %%
def scat_plot(x, y, data):
    sns.regplot(x = x, y = y, data = df_clean, order = 3,
                scatter_kws = {"color": "steelblue"}, line_kws = {"color": "black"})
    plt.ticklabel_format(style = 'plain', axis = 'y')
    plt.title(x)
    plt.show()

# %%
columns = ['Rooms', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 
           'Landsize', 'BuildingArea', 'YearBuilt', 'Propertycount']

for i in columns:
    scat_plot(i, 'Price', df_clean)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
ts = df_clean.loc[:, ['Date', 'Price']].groupby('Date').median()

# %%
sns.lineplot(x = 'Date', y = 'Price', data = ts)

plt.ticklabel_format(style = 'plain', axis = 'y')

plt.xticks(rotation = 25)

plt.show()

# %% [markdown]
# - Há bairros/regiões em que as propriedades são mais valiosas. Essas regiões costumam ficar mais próximas de CBD de Melbourne. Podemos dizer mais ou menos em regiões centrais mais valiosas do que regiões periféricas;
# -
